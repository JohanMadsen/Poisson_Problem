# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def surface_plot (matrix, **kwargs):
    # acquire the cartesian coordinate matrices from the matrix
    # x is cols, y is rows
    a = 2*(np.arange(matrix.shape[0])/matrix.shape[0]-0.5)
    b = 2*(np.arange(matrix.shape[1])/matrix.shape[1]-0.5)
    (x, y) = np.meshgrid(a,b)
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111, projection='3d')
    surf = ax.plot_surface(x, y, matrix, **kwargs)
    ax.view_init(30, 55+180)
    fig.tight_layout()
    return (fig, ax, surf)

# %%
m = np.loadtxt("test.txt")

cmap = mpl.cm.jet(np.linspace(0,1,50))
cmap = mpl.colors.ListedColormap(cmap[5:,:40])

(fig, ax, surf) = surface_plot(m, cmap=cmap)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('U')
ax.set_title("Plot of U on X,Y surface", fontsize=18)

plt.savefig("verify.png", transparant=True)

plt.show()

# %%
Ps = [i for i in range(1,17)]
f = 0.9993
amdahls = [1 / ((f/i +1-f)) for i in Ps]
Ps
amdahls
# Out:
# [1.0000000000000002,
#  1.99860097931448,
#  2.995805871779509,
#  3.9916176030336294,
#  4.986039090546471,
#  5.9790732436472345,
#  6.970722963553078,
#  7.960991143397352,
#  8.949880668257755,
#  9.937394415184327,
#  10.923535253227415,
#  11.908306043465315,
#  12.891709639032138,
#  13.873748885145156,
#  14.854426619132516,
#  15.833745670460134]

# %%
plt.plot(Ps, amdahls)
plt.plot(Ps, Ps)
